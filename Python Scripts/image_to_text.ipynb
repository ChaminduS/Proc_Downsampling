# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.resize(cv.imread('rose.jpg', 0), (256,256))

print(img.shape)
plt.imshow(img, cmap = 'gray')
# Out:
# (256, 256)

# %%
img_array =np.array(img)
img_array_cropped = img[0:-1,:]
img_array_cropped.shape
plt.imshow(img_array_cropped, cmap='gray')

# %%
cropped_img_flatten = img_array_cropped.flatten()
cropped_img_flatten.shape
# Out:
# (65280,)

# %%
final_array = np.zeros((cropped_img_flatten.shape[0]+1,)).astype(np.uint8)
final_array[0] = 255
final_array[1:] = cropped_img_flatten

# %%
img_array_cropped
# Out:
# array([[44, 45, 49, ..., 14, 14, 13],
#        [44, 45, 49, ..., 14, 14, 13],
#        [44, 45, 49, ..., 14, 14, 13],
#        ...,
#        [30, 30, 30, ..., 27, 27, 26],
#        [31, 31, 31, ..., 27, 27, 26],
#        [31, 31, 31, ..., 28, 28, 27]], dtype=uint8)

# %%
cropped_img_flatten
# Out:
# array([44, 45, 49, ..., 28, 28, 27], dtype=uint8)

# %%
final_array
# Out:
# array([255,  44,  45, ...,  28,  28,  27], dtype=uint8)

# %%
with open('image.txt', 'w') as f:
  for i in range(final_array.shape[0]-1):
    f.write('{0:08b}\n'.format(final_array[i]))
  f.write('{0:08b}'.format(final_array[final_array.shape[0]-1]))
